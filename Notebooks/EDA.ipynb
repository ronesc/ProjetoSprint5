# %%
import pandas as pd
import plotly.express as px
# ...existing code...
car_data = pd.read_csv('Spotify Youtube Dataset.csv') # lendo os dados


fig = px.histogram(car_data, x="Stream")  # Histograma de streams no Spotify
fig.show()
fig.show() # exibindo
